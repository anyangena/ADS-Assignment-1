# %%
import pandas as pd

# %%
alumni=pd.read_csv('data/alumni.csv')
alumni
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0             2004    Male         Single      Standard Diploma       Yes
# 1             2005    Male        Married  College Prep Diploma        No
# 2             2006  Female         Single      Standard Diploma       Yes
# 3             2007    Male        Married      Standard Diploma        No
# 4             2006  Female       Divorced      Standard Diploma       Yes
# ..             ...     ...            ...                   ...       ...
# 83            2007    Male         Single      Standard Diploma        No
# 84            2008       M         Single  College Prep Diploma       Yes
# 85            2009    Male        Married      Standard Diploma        No
# 86            2005  Female       Divorced      Standard Diploma       Yes
# 87            2006    Male        Married      Standard Diploma       Yes
#
#     Salary    Fee Savings ($)
# 0   125000  10869     $86,000
# ...

# %%
alumni.head(50)
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0             2004    Male         Single      Standard Diploma       Yes
# 1             2005    Male        Married  College Prep Diploma        No
# 2             2006  Female         Single      Standard Diploma       Yes
# 3             2007    Male        Married      Standard Diploma        No
# 4             2006  Female       Divorced      Standard Diploma       Yes
# 5             2007  Female        Married  College Prep Diploma        No
# 6             2006    Male       Divorced      Standard Diploma        No
# 7             2006  Female         Single  College Prep Diploma       Yes
# 8             2007    Male        Married      Standard Diploma        No
# 9             2005  Female         Single      Standard Diploma       Yes
# 10            2006  Female         Single      Standard Diploma       Yes
# 11            2007  Female        Married      Standard Diploma        No
# ...

# %%
alumni.tail()
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 83            2007    Male         Single      Standard Diploma        No
# 84            2008       M         Single  College Prep Diploma       Yes
# 85            2009    Male        Married      Standard Diploma        No
# 86            2005  Female       Divorced      Standard Diploma       Yes
# 87            2006    Male        Married      Standard Diploma       Yes
#
#     Salary    Fee Savings ($)
# 83   75000  12066     $16,000
# 84   65000  12066     $72,000
# 85   75000  12066     $46,000
# 86  100000  12067     $32,000
# 87   75000  12067     $67,000

# %%
alumni.dtypes
# Out:
# Year Graduated     int64
# Gender            object
# Marital Status    object
# Diploma Type      object
# Defaulted         object
# Salary             int64
# Fee                int64
# Savings ($)       object
# dtype: object

# %%
alumni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year Graduated  88 non-null     int64
#  1   Gender          88 non-null     object
#  2   Marital Status  88 non-null     object
#  3   Diploma Type    88 non-null     object
#  4   Defaulted       88 non-null     object
#  5   Salary          88 non-null     int64
#  6   Fee             88 non-null     int64
#  7   Savings ($)     88 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 5.6+ KB

# %%
alumni.describe()
# Out:
#        Year Graduated         Salary           Fee
# count       88.000000      88.000000     88.000000
# mean      2006.477273   84090.909091  11708.727273
# std          1.560852   21234.128008   1110.647949
# min       2004.000000   35000.000000  10869.000000
# 25%       2005.000000   75000.000000  10968.000000
# 50%       2006.500000   75000.000000  11696.000000
# 75%       2008.000000   90000.000000  12058.250000
# max       2009.000000  160000.000000  20960.000000

# %%
def clean_currency(curr):
    return float(curr.replace(',','').replace('$',''))
alumni['Savings']=alumni['Savings ($)'].apply(clean_currency)
alumni.head(50)
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0             2004    Male         Single      Standard Diploma       Yes
# 1             2005    Male        Married  College Prep Diploma        No
# 2             2006  Female         Single      Standard Diploma       Yes
# 3             2007    Male        Married      Standard Diploma        No
# 4             2006  Female       Divorced      Standard Diploma       Yes
# 5             2007  Female        Married  College Prep Diploma        No
# 6             2006    Male       Divorced      Standard Diploma        No
# 7             2006  Female         Single  College Prep Diploma       Yes
# 8             2007    Male        Married      Standard Diploma        No
# 9             2005  Female         Single      Standard Diploma       Yes
# 10            2006  Female         Single      Standard Diploma       Yes
# 11            2007  Female        Married      Standard Diploma        No
# ...

# %%
alumni['Savings'].describe()
# Out:
# count        88.000000
# mean      47954.545455
# std       28324.437721
# min        6000.000000
# 25%       30000.000000
# 50%       46000.000000
# 75%       67000.000000
# max      146000.000000
# Name: Savings, dtype: float64

# %%
alumni.dtypes.Savings
# Out:
# dtype('float64')

# %% [markdown]
# ## Question 4 : Cleaning the data set - part B

# %% [markdown]
# ## a) Run the 'alumni["Gender"].value_counts()' to see the incorrect 'M' fields that need to be converted to 'Male'

# %%
alumni['Gender'].value_counts()
# Out:
# Male      46
# Female    39
# M          3
# Name: Gender, dtype: int64

# %% [markdown]
# ## Now use a '.str.replace' on the 'Gender' column to covert the incorrect 'M' fields. Hint: We must use ^...$ to restrict the pattern to match the whole string.

# %%
alumni['Gender'].str.replace("^M$","Male")
# Out:
# <ipython-input-3-0c7c8bae85af>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   alumni['Gender'].str.replace("^M$","Male")
# 0       Male
# 1       Male
# 2     Female
# 3       Male
# 4     Female
#        ...
# 83      Male
# 84      Male
# 85      Male
# 86    Female
# 87      Male
# Name: Gender, Length: 88, dtype: object

# %%
alumni
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0             2004    Male         Single      Standard Diploma       Yes
# 1             2005    Male        Married  College Prep Diploma        No
# 2             2006  Female         Single      Standard Diploma       Yes
# 3             2007    Male        Married      Standard Diploma        No
# 4             2006  Female       Divorced      Standard Diploma       Yes
# ..             ...     ...            ...                   ...       ...
# 83            2007    Male         Single      Standard Diploma        No
# 84            2008       M         Single  College Prep Diploma       Yes
# 85            2009    Male        Married      Standard Diploma        No
# 86            2005  Female       Divorced      Standard Diploma       Yes
# 87            2006    Male        Married      Standard Diploma       Yes
#
#     Salary    Fee Savings ($)   Savings
# ...

# %% [markdown]
# ## c) That didn't the set alumni["Gender"] column however. You will need to update the column when using the replace command 'alumni["Gender"]=', show how this is done below

# %%
alumni['Gender']=alumni['Gender'].replace(to_replace=['M'],value='Male')
alumni
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0             2004    Male         Single      Standard Diploma       Yes
# 1             2005    Male        Married  College Prep Diploma        No
# 2             2006  Female         Single      Standard Diploma       Yes
# 3             2007    Male        Married      Standard Diploma        No
# 4             2006  Female       Divorced      Standard Diploma       Yes
# ..             ...     ...            ...                   ...       ...
# 83            2007    Male         Single      Standard Diploma        No
# 84            2008    Male         Single  College Prep Diploma       Yes
# 85            2009    Male        Married      Standard Diploma        No
# 86            2005  Female       Divorced      Standard Diploma       Yes
# 87            2006    Male        Married      Standard Diploma       Yes
#
#     Salary    Fee Savings ($)   Savings
# ...

# %%
alumni
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0             2004    Male         Single      Standard Diploma       Yes
# 1             2005    Male        Married  College Prep Diploma        No
# 2             2006  Female         Single      Standard Diploma       Yes
# 3             2007    Male        Married      Standard Diploma        No
# 4             2006  Female       Divorced      Standard Diploma       Yes
# ..             ...     ...            ...                   ...       ...
# 83            2007    Male         Single      Standard Diploma        No
# 84            2008    Male         Single  College Prep Diploma       Yes
# 85            2009    Male        Married      Standard Diploma        No
# 86            2005  Female       Divorced      Standard Diploma       Yes
# 87            2006    Male        Married      Standard Diploma       Yes
#
#     Salary    Fee Savings ($)   Savings
# ...

# %% [markdown]
# ## You can set it directly by using the df.loc command, show how this can be done by using the 'df.loc[row_indexer,col_indexer] = value' command to convert the 'M' to 'Male'

# %%
alumni.loc[alumni.Gender=='M']='Male'
alumni
# Out:
#    Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0            2004    Male         Single      Standard Diploma       Yes
# 1            2005    Male        Married  College Prep Diploma        No
# 2            2006  Female         Single      Standard Diploma       Yes
# 3            2007    Male        Married      Standard Diploma        No
# 4            2006  Female       Divorced      Standard Diploma       Yes
# ..            ...     ...            ...                   ...       ...
# 83           2007    Male         Single      Standard Diploma        No
# 84           2008    Male         Single  College Prep Diploma       Yes
# 85           2009    Male        Married      Standard Diploma        No
# 86           2005  Female       Divorced      Standard Diploma       Yes
# 87           2006    Male        Married      Standard Diploma       Yes
#
#     Salary    Fee Savings ($)   Savings
# 0   125000  10869     $86,000   86000.0
# ...

# %% [markdown]
# ## Now run the 'value_counts' for Gender again to see the correct columns - 'Male' and 'Female'

# %%
alumni['Gender'].value_counts()
# Out:
# Male      49
# Female    39
# Name: Gender, dtype: int64

# %% [markdown]
# ## a) get the median, b) mean and c) standard deviation for the 'Salary' column

# %%
alumni['Salary'].mean()
# Out:
# 84090.90909090909

# %%
alumni['Salary'].median()
# Out:
# 75000.0

# %%
alumni['Salary'].median()
# Out:
# 21234.1280081736

# %% [markdown]
# ## d) identify which alumni paid more than $15000 in fees, using the 'Fee' column

# %%
alumni_rst = alumni.loc[alumni['Fee']>15000]
alumni_rst
# Out:
#    Year Graduated Gender Marital Status      Diploma Type Defaulted  Salary  \
# 18           2006   Male        Married  Standard Diploma        No  140000
#
#       Fee Savings ($)  Savings
# 18  20960     $72,000  72000.0

# %% [markdown]
# ## visualisation

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## barplot using diploma type column

# %%
import seaborn as sns
sns.displot(data=alumni, x="Diploma Type")

# %% [markdown]
# ### boxplot

# %%
sns.boxplot(data=alumni,x='Salary',y='Savings')
plt.xticks(rotation='vertical', size=10)
fig = plt.figure(figsize =(10, 7))

# %%
## histogram with salary column use 12 bins

# %%
sns.histplot(data=alumni,x='Salary')
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Count'>

# %%
plt.hist(alumni['Salary'],bins=12,histtype='bar', rwidth=0.8)
plt.xlabel('marks')
plt.ylabel('count')
plt.title(' Graph Histogram')
plt.show()

# %% [markdown]
# ### scatterplot

# %%
sns.scatterplot(data=alumni,x='Salary',y='Savings')
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Savings'>

# %% [markdown]
# ## contigency table

# %%
alumni.crosstab=(alumni['Marital Status'],alumni['Defaulted'])
alumni.crosstab
# Out:
# <ipython-input-52-3129a377288d>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   alumni.crosstab=(alumni['Marital Status'],alumni['Defaulted'])
# (0       Single
#  1      Married
#  2       Single
#  3      Married
#  4     Divorced
#          ...
#  83      Single
#  84      Single
#  85     Married
#  86    Divorced
#  87     Married
#  Name: Marital Status, Length: 88, dtype: object,
#  0     Yes
#  1      No
#  2     Yes
#  3      No
#  4     Yes
#       ...
#  83     No
#  84    Yes
#  85     No
#  86    Yes
#  87    Yes
#  Name: Defaulted, Length: 88, dtype: object)
